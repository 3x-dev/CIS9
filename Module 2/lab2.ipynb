# %% [markdown]
# #### CIS 9 - Lab 2
# Topics: Pandas, Matplotlib

# %%
# Name: Aryan Singhal

# %% [markdown]
# In this lab we will continue with the student enrollment data at California community colleges and do some deeper analysis and visualization.<br>
# The data is still from the same [source](https://datamart.cccco.edu/Students/Enrollment_Status.aspx), but this time it's in the raw format (as downloaded from the website) and is in the input file `enrollment.xlsx`.<br>
# The file has the names of all the community colleges, and student counts for each term, from Fall 2013 to Winter 2024.
#
# There are 2 main parts to this lab:<br>
# A. Data cleaning<br>
# B. Data analysis and visualization

# %%
# import files
import pandas as pd
df = pd.read_excel('enrollment.xlsx')

# %% [markdown]
# ---
# ### Data Cleaning: remove unnecessary data

# %% [markdown]
# 1. __Read data from the file `enrollment.xlsx` into a DataFrame__<br>
# Then __print the DataFrame__.
#
# _Note: For all DataFrames in this class, make sure you use the notebook <u>graphical print</u>, not the Python text printing._

# %%
df
# Out:
#              Unnamed: 0      Fall 2013        Fall 2013.1    Winter 2014  \
# 0          College Name  Student Count  Student Count (%)  Student Count
# 1               Alameda           6143             0.0037            NaN
# 2         Allan Hancock          15553             0.0093            NaN
# 3        American River          30062              0.018            NaN
# 4       Antelope Valley          14459             0.0087           2874
# ..                  ...            ...                ...            ...
# 117  West Hills Lemoore           4425             0.0027            NaN
# 118             West LA          10854             0.0065           2181
# 119         West Valley          11387             0.0068            NaN
# 120            Woodland           2776             0.0017            NaN
# 121                Yuba           7002             0.0042            NaN
#
#          Winter 2014.1    Spring 2014      Spring 2014.1    Summer 2014  \
# 0    Student Count (%)  Student Count  Student Count (%)  Student Count
# 1                    0           6879             0.0042           2672
# 2                    0          16894             0.0102           7653
# 3                    0          30301             0.0184          10032
# 4               0.0142          14501             0.0088           4222
# ..                 ...            ...                ...            ...
# 117                  0           4372             0.0026           2067
# 118             0.0108          10289             0.0062           2763
# 119                  0          13245              0.008           5951
# 120                  0           2723             0.0016            824
# 121                  0           6871             0.0042           2773
#
#          Summer 2014.1      Fall 2014  ...    Winter 2023      Winter 2023.1  \
# 0    Student Count (%)  Student Count  ...  Student Count  Student Count (%)
# 1               0.0038           6017  ...            NaN                  0
# 2               0.0109          16461  ...           1473              0.007
# 3               0.0143          29774  ...            NaN                  0
# 4                0.006          14656  ...            NaN                  0
# ..                 ...            ...  ...            ...                ...
# 117             0.0029           4283  ...            NaN                  0
# 118             0.0039          10881  ...           3199             0.0153
# 119             0.0085          11254  ...           1481             0.0071
# 120             0.0012           2619  ...            NaN                  0
# 121             0.0039           6793  ...            NaN                  0
#
#        Spring 2023      Spring 2023.1    Summer 2023      Summer 2023.1  \
# 0    Student Count  Student Count (%)  Student Count  Student Count (%)
# 1             5323             0.0038           2122             0.0028
# 2            12327             0.0089           5478             0.0072
# 3            27785             0.0201          12770             0.0167
# 4            11205             0.0081           5921             0.0077
# ..             ...                ...            ...                ...
# 117           4200              0.003           2265              0.003
# 118           9488             0.0069           5934             0.0077
# 119           8094             0.0058           4652             0.0061
# 120           3817             0.0028           1576             0.0021
# 121           5495              0.004           2802             0.0037
#
#          Fall 2023        Fall 2023.1    Winter 2024      Winter 2024.1
# 0    Student Count  Student Count (%)  Student Count  Student Count (%)
# 1             5859             0.0039            NaN                  0
# 2            12873             0.0085           1818             0.0114
# 3            29908             0.0198            NaN                  0
# 4            13095             0.0087            NaN                  0
# ..             ...                ...            ...                ...
# 117           4245             0.0028            NaN                  0
# 118           9955             0.0066           3669             0.0231
# 119           9283             0.0061           1574             0.0099
# 120           3844             0.0025            NaN                  0
# 121           5851             0.0039            NaN                  0
#
# [122 rows x 85 columns]

# %% [markdown]
# 2. Change the index of each row to the college name by doing the following 2 steps.
#
# 2a. __Print the column label__ (the header) of the column with college names, so you can see the exact string.

# %%
print(df.columns[0])
# Out:
# Unnamed: 0

# %% [markdown]
# 2b. Use the string of part 2a to __change the row indices to college names__.<br>
# This makes it easier to select a college, by using its name instead of an index number.<br>
# Then __print the DataFrame__ to show that it's changed.

# %%
df.set_index(df.columns[0], inplace=True)
df
# Out:
#                         Fall 2013        Fall 2013.1    Winter 2014  \
# Unnamed: 0
# College Name        Student Count  Student Count (%)  Student Count
# Alameda                      6143             0.0037            NaN
# Allan Hancock               15553             0.0093            NaN
# American River              30062              0.018            NaN
# Antelope Valley             14459             0.0087           2874
# ...                           ...                ...            ...
# West Hills Lemoore           4425             0.0027            NaN
# West LA                     10854             0.0065           2181
# West Valley                 11387             0.0068            NaN
# Woodland                     2776             0.0017            NaN
# Yuba                         7002             0.0042            NaN
#
#                         Winter 2014.1    Spring 2014      Spring 2014.1  \
# Unnamed: 0
# College Name        Student Count (%)  Student Count  Student Count (%)
# Alameda                             0           6879             0.0042
# Allan Hancock                       0          16894             0.0102
# American River                      0          30301             0.0184
# Antelope Valley                0.0142          14501             0.0088
# ...                               ...            ...                ...
# West Hills Lemoore                  0           4372             0.0026
# West LA                        0.0108          10289             0.0062
# West Valley                         0          13245              0.008
# Woodland                            0           2723             0.0016
# Yuba                                0           6871             0.0042
#
#                       Summer 2014      Summer 2014.1      Fall 2014  \
# Unnamed: 0
# College Name        Student Count  Student Count (%)  Student Count
# Alameda                      2672             0.0038           6017
# Allan Hancock                7653             0.0109          16461
# American River              10032             0.0143          29774
# Antelope Valley              4222              0.006          14656
# ...                           ...                ...            ...
# West Hills Lemoore           2067             0.0029           4283
# West LA                      2763             0.0039          10881
# West Valley                  5951             0.0085          11254
# Woodland                      824             0.0012           2619
# Yuba                         2773             0.0039           6793
#
#                           Fall 2014.1  ...    Winter 2023      Winter 2023.1  \
# Unnamed: 0                             ...
# College Name        Student Count (%)  ...  Student Count  Student Count (%)
# Alameda                        0.0036  ...            NaN                  0
# Allan Hancock                  0.0099  ...           1473              0.007
# American River                 0.0179  ...            NaN                  0
# Antelope Valley                0.0088  ...            NaN                  0
# ...                               ...  ...            ...                ...
# West Hills Lemoore             0.0026  ...            NaN                  0
# West LA                        0.0065  ...           3199             0.0153
# West Valley                    0.0067  ...           1481             0.0071
# Woodland                       0.0016  ...            NaN                  0
# Yuba                           0.0041  ...            NaN                  0
#
#                       Spring 2023      Spring 2023.1    Summer 2023  \
# Unnamed: 0
# College Name        Student Count  Student Count (%)  Student Count
# Alameda                      5323             0.0038           2122
# Allan Hancock               12327             0.0089           5478
# American River              27785             0.0201          12770
# Antelope Valley             11205             0.0081           5921
# ...                           ...                ...            ...
# West Hills Lemoore           4200              0.003           2265
# West LA                      9488             0.0069           5934
# West Valley                  8094             0.0058           4652
# Woodland                     3817             0.0028           1576
# Yuba                         5495              0.004           2802
#
#                         Summer 2023.1      Fall 2023        Fall 2023.1  \
# Unnamed: 0
# College Name        Student Count (%)  Student Count  Student Count (%)
# Alameda                        0.0028           5859             0.0039
# Allan Hancock                  0.0072          12873             0.0085
# American River                 0.0167          29908             0.0198
# Antelope Valley                0.0077          13095             0.0087
# ...                               ...            ...                ...
# West Hills Lemoore              0.003           4245             0.0028
# West LA                        0.0077           9955             0.0066
# West Valley                    0.0061           9283             0.0061
# Woodland                       0.0021           3844             0.0025
# Yuba                           0.0037           5851             0.0039
#
#                       Winter 2024      Winter 2024.1
# Unnamed: 0
# College Name        Student Count  Student Count (%)
# Alameda                       NaN                  0
# Allan Hancock                1818             0.0114
# American River                NaN                  0
# Antelope Valley               NaN                  0
# ...                           ...                ...
# West Hills Lemoore            NaN                  0
# West LA                      3669             0.0231
# West Valley                  1574             0.0099
# Woodland                      NaN                  0
# Yuba                          NaN                  0
#
# [122 rows x 84 columns]

# %% [markdown]
# 3. For every term there are 2 columns of data: the number of students, and the number as a percentage.<br>
# For example, the first 2 columns "Fall 2013" and "Fall 2013.1" are both for Fall 2013.<br>
# The percentage is not needed for the analysis because we are investigating the actual number of students.<br>
# __Remove all the percentage columns__ by doing the following steps:
# - Create a sequence of every other index values, starting at: 1, 3, 5, 7...
# - Use this sequence to remove all the percentage columns, which are at index 1, 3, 5, 7...<br>
# You should not have to use a loop, and you should not have to type in the actual column labels.
#
# Then __print the first 5 rows of the resulting DataFrame__.

# %%
df = df.iloc[:, [i for i in range(len(df.columns)) if i % 2 == 0]]
df.head()
# Out:
#                      Fall 2013    Winter 2014    Spring 2014    Summer 2014  \
# Unnamed: 0
# College Name     Student Count  Student Count  Student Count  Student Count
# Alameda                   6143            NaN           6879           2672
# Allan Hancock            15553            NaN          16894           7653
# American River           30062            NaN          30301          10032
# Antelope Valley          14459           2874          14501           4222
#
#                      Fall 2014    Winter 2015    Spring 2015    Summer 2015  \
# Unnamed: 0
# College Name     Student Count  Student Count  Student Count  Student Count
# Alameda                   6017            NaN           6555           2501
# Allan Hancock            16461            NaN          17724           7991
# American River           29774            NaN          30338          11566
# Antelope Valley          14656           2963          14385           4812
#
#                      Fall 2015    Winter 2016  ...      Fall 2021  \
# Unnamed: 0                                     ...
# College Name     Student Count  Student Count  ...  Student Count
# Alameda                   6432            NaN  ...           5204
# Allan Hancock            15712           1079  ...          12208
# American River           30022            NaN  ...          26395
# Antelope Valley          14739           2990  ...          11396
#
#                    Winter 2022    Spring 2022    Summer 2022      Fall 2022  \
# Unnamed: 0
# College Name     Student Count  Student Count  Student Count  Student Count
# Alameda                    NaN           4798           1648           5704
# Allan Hancock             1221          11858           5192          11984
# American River             NaN          26103          10054          27430
# Antelope Valley            NaN          10194           5147          12015
#
#                    Winter 2023    Spring 2023    Summer 2023      Fall 2023  \
# Unnamed: 0
# College Name     Student Count  Student Count  Student Count  Student Count
# Alameda                    NaN           5323           2122           5859
# Allan Hancock             1473          12327           5478          12873
# American River             NaN          27785          12770          29908
# Antelope Valley            NaN          11205           5921          13095
#
#                    Winter 2024
# Unnamed: 0
# College Name     Student Count
# Alameda                    NaN
# Allan Hancock             1818
# American River             NaN
# Antelope Valley            NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# 4. In the output of the step above, note that the top row of data now contains only the string 'Student Count', which is not needed.<br>
# __Remove the top row of data__, and __print the first rows of the DataFrame__ to show the change.<br>
# Then __print the number of rows__ of the DataFrame. It should be one less than the number of rows shown in step 1.

# %%
df = df.iloc[1:] 
df.head()
print(f"Number of rows: {len(df)}")
# Out:
# Number of rows: 121

# %% [markdown]
# 5. Make sure the datatype of data are numeric values by doing the following 3 steps.
#
# 5a. __Show the data type of each column of data__.

# %%
print(df.dtypes)
# Out:
# Fall 2013      object
# Winter 2014    object
# Spring 2014    object
# Summer 2014    object
# Fall 2014      object
# Winter 2015    object
# Spring 2015    object
# Summer 2015    object
# Fall 2015      object
# Winter 2016    object
# Spring 2016    object
# Summer 2016    object
# Fall 2016      object
# Winter 2017    object
# Spring 2017    object
# Summer 2017    object
# Fall 2017      object
# Winter 2018    object
# Spring 2018    object
# Summer 2018    object
# Fall 2018      object
# Winter 2019    object
# Spring 2019    object
# Summer 2019    object
# Fall 2019      object
# Winter 2020    object
# Spring 2020    object
# Summer 2020    object
# Fall 2020      object
# Winter 2021    object
# Spring 2021    object
# Summer 2021    object
# Fall 2021      object
# Winter 2022    object
# Spring 2022    object
# Summer 2022    object
# Fall 2022      object
# Winter 2023    object
# Spring 2023    object
# Summer 2023    object
# Fall 2023      object
# Winter 2024    object
# dtype: object

# %% [markdown]
# 5b. __Create a Raw NBConvert cell to explain why the data are not numbers__.

# %% [markdown]
# The data might not be numbers due to the presence of characters or symbols
# that were not cleaned during the data ingestion process. This can include
# commas in numbers, strings or other non-numeric symbols that must be converted or removed.

# %% [markdown]
# 5c. __Convert the data to floats__, then __print the first rows of the DataFrame__.

# %%
df = df.apply(pd.to_numeric, errors='coerce')
df.head()
# Out:
#                  Fall 2013  Winter 2014  Spring 2014  Summer 2014  Fall 2014  \
# Unnamed: 0
# Alameda             6143.0          NaN       6879.0       2672.0     6017.0
# Allan Hancock      15553.0          NaN      16894.0       7653.0    16461.0
# American River     30062.0          NaN      30301.0      10032.0    29774.0
# Antelope Valley    14459.0       2874.0      14501.0       4222.0    14656.0
# Bakersfield        17845.0          NaN      18050.0       7647.0    18819.0
#
#                  Winter 2015  Spring 2015  Summer 2015  Fall 2015  \
# Unnamed: 0
# Alameda                  NaN       6555.0       2501.0     6432.0
# Allan Hancock            NaN      17724.0       7991.0    15712.0
# American River           NaN      30338.0      11566.0    30022.0
# Antelope Valley       2963.0      14385.0       4812.0    14739.0
# Bakersfield              NaN      18468.0       8527.0    20576.0
#
#                  Winter 2016  ...  Fall 2021  Winter 2022  Spring 2022  \
# Unnamed: 0                    ...
# Alameda                  NaN  ...     5204.0          NaN       4798.0
# Allan Hancock         1079.0  ...    12208.0       1221.0      11858.0
# American River           NaN  ...    26395.0          NaN      26103.0
# Antelope Valley       2990.0  ...    11396.0          NaN      10194.0
# Bakersfield              NaN  ...    25242.0          NaN      24934.0
#
#                  Summer 2022  Fall 2022  Winter 2023  Spring 2023  \
# Unnamed: 0
# Alameda               1648.0     5704.0          NaN       5323.0
# Allan Hancock         5192.0    11984.0       1473.0      12327.0
# American River       10054.0    27430.0          NaN      27785.0
# Antelope Valley       5147.0    12015.0          NaN      11205.0
# Bakersfield          16094.0    27896.0          NaN      27502.0
#
#                  Summer 2023  Fall 2023  Winter 2024
# Unnamed: 0
# Alameda               2122.0     5859.0          NaN
# Allan Hancock         5478.0    12873.0       1818.0
# American River       12770.0    29908.0          NaN
# Antelope Valley       5921.0    13095.0          NaN
# Bakersfield          17812.0    31049.0          NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ---
# ### Data Cleaning: remove incomplete data

# %% [markdown]
# 6. Do the following steps to remove colleges that are not opened during the last 10 years.<br>
# These colleges have NaNs for all quarters of certain years.
#
# 6a. __Create a temporary DataFrame that doesn't contain the Winter quarters__.<br>
# This will remove the NaNs due to a college being on a semester system, which has no Winter term.<br>
# Then __print the first few rows of the temporary DataFrame__.
#
# _Hint: Winter quarters appear at every 4 columns, starting at column index 1_

# %%
winter_columns = [i for i in range(1, len(df.columns), 4)]
temp_df = df.drop(df.columns[winter_columns], axis=1)
temp_df.head()
# Out:
#                  Fall 2013  Spring 2014  Summer 2014  Fall 2014  Spring 2015  \
# Unnamed: 0
# Alameda             6143.0       6879.0       2672.0     6017.0       6555.0
# Allan Hancock      15553.0      16894.0       7653.0    16461.0      17724.0
# American River     30062.0      30301.0      10032.0    29774.0      30338.0
# Antelope Valley    14459.0      14501.0       4222.0    14656.0      14385.0
# Bakersfield        17845.0      18050.0       7647.0    18819.0      18468.0
#
#                  Summer 2015  Fall 2015  Spring 2016  Summer 2016  Fall 2016  \
# Unnamed: 0
# Alameda               2501.0     6432.0       6881.0       2376.0     6558.0
# Allan Hancock         7991.0    15712.0      17303.0       7429.0    15647.0
# American River       11566.0    30022.0      32966.0      13362.0    31197.0
# Antelope Valley       4812.0    14739.0      14239.0       5079.0    14526.0
# Bakersfield           8527.0    20576.0      20144.0       9885.0    23008.0
#
#                  ...  Fall 2020  Spring 2021  Summer 2021  Fall 2021  \
# Unnamed: 0       ...
# Alameda          ...     5985.0       5670.0       1610.0     5204.0
# Allan Hancock    ...    11276.0      11344.0       5108.0    12208.0
# American River   ...    25957.0      24802.0      10589.0    26395.0
# Antelope Valley  ...    12324.0      11093.0       5162.0    11396.0
# Bakersfield      ...    25707.0      23755.0      13311.0    25242.0
#
#                  Spring 2022  Summer 2022  Fall 2022  Spring 2023  \
# Unnamed: 0
# Alameda               4798.0       1648.0     5704.0       5323.0
# Allan Hancock        11858.0       5192.0    11984.0      12327.0
# American River       26103.0      10054.0    27430.0      27785.0
# Antelope Valley      10194.0       5147.0    12015.0      11205.0
# Bakersfield          24934.0      16094.0    27896.0      27502.0
#
#                  Summer 2023  Fall 2023
# Unnamed: 0
# Alameda               2122.0     5859.0
# Allan Hancock         5478.0    12873.0
# American River       12770.0    29908.0
# Antelope Valley       5921.0    13095.0
# Bakersfield          17812.0    31049.0
#
# [5 rows x 31 columns]

# %% [markdown]
# 6b. __Print all rows of the temporary DataFrame that have NaNs__.

# %%
nan_rows = temp_df[temp_df.isna().all(axis=1)]
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [Fall 2013, Spring 2014, Summer 2014, Fall 2014, Spring 2015, Summer 2015, Fall 2015, Spring 2016, Summer 2016, Fall 2016, Spring 2017, Summer 2017, Fall 2017, Spring 2018, Summer 2018, Fall 2018, Spring 2019, Summer 2019, Fall 2019, Spring 2020, Summer 2020, Fall 2020, Spring 2021, Summer 2021, Fall 2021, Spring 2022, Summer 2022, Fall 2022, Spring 2023, Summer 2023, Fall 2023]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# 6c. __Create a Raw NBConvert cell to explain__:<br>
# Which colleges started less than 10 years ago?
# Which colleges closed in the last 10 years?

# %% [markdown]
# To identify colleges that started less than 10 years ago or closed in the last 10 years, we look for continuous NaN entries in the DataFrame. Continuous NaNs in the later years might indicate recent closures, whereas NaNs in the early years could suggest a more recent establishment of the institution. The DataFrame rows printed in the previous step help in identifying these cases.

# %% [markdown]
# 6d. Use the college names you found in part 6b to __remove these colleges from the cleaned DataFrame from step 5c__.<br>
# Then __print the number of rows of the DataFrame__ to confirm that you've removed the rows,<br>
# and __print the first rows of the DataFrame__.
#
#
# _You should not have to type the names of the colleges in your answer._

# %%
clean_df = df.drop(nan_rows.index)
print(f"Number of rows after removal: {len(clean_df)}")
clean_df.head()
# Out:
# Number of rows after removal: 121
#                  Fall 2013  Winter 2014  Spring 2014  Summer 2014  Fall 2014  \
# Unnamed: 0
# Alameda             6143.0          NaN       6879.0       2672.0     6017.0
# Allan Hancock      15553.0          NaN      16894.0       7653.0    16461.0
# American River     30062.0          NaN      30301.0      10032.0    29774.0
# Antelope Valley    14459.0       2874.0      14501.0       4222.0    14656.0
# Bakersfield        17845.0          NaN      18050.0       7647.0    18819.0
#
#                  Winter 2015  Spring 2015  Summer 2015  Fall 2015  \
# Unnamed: 0
# Alameda                  NaN       6555.0       2501.0     6432.0
# Allan Hancock            NaN      17724.0       7991.0    15712.0
# American River           NaN      30338.0      11566.0    30022.0
# Antelope Valley       2963.0      14385.0       4812.0    14739.0
# Bakersfield              NaN      18468.0       8527.0    20576.0
#
#                  Winter 2016  ...  Fall 2021  Winter 2022  Spring 2022  \
# Unnamed: 0                    ...
# Alameda                  NaN  ...     5204.0          NaN       4798.0
# Allan Hancock         1079.0  ...    12208.0       1221.0      11858.0
# American River           NaN  ...    26395.0          NaN      26103.0
# Antelope Valley       2990.0  ...    11396.0          NaN      10194.0
# Bakersfield              NaN  ...    25242.0          NaN      24934.0
#
#                  Summer 2022  Fall 2022  Winter 2023  Spring 2023  \
# Unnamed: 0
# Alameda               1648.0     5704.0          NaN       5323.0
# Allan Hancock         5192.0    11984.0       1473.0      12327.0
# American River       10054.0    27430.0          NaN      27785.0
# Antelope Valley       5147.0    12015.0          NaN      11205.0
# Bakersfield          16094.0    27896.0          NaN      27502.0
#
#                  Summer 2023  Fall 2023  Winter 2024
# Unnamed: 0
# Alameda               2122.0     5859.0          NaN
# Allan Hancock         5478.0    12873.0       1818.0
# American River       12770.0    29908.0          NaN
# Antelope Valley       5921.0    13095.0          NaN
# Bakersfield          17812.0    31049.0          NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ---
# ### Data Analysis and Visualization

# %% [markdown]
# #### A. Colleges on quarter systems

# %% [markdown]
# 7. Now that the dataset has been cleaned of unnecessary data and incomplete data, we investigate the remaining NaNs.
#
# 7a. Note from the DataFrame of step 6d that many of the colleges show NaN for the Winter terms.<br>
# These colleges are on a semester system and only have Fall, Spring, and Summer semesters.<br>
# Other colleges, like De Anza, are on a quarter system and have a Winter quarter.
#
# __Find the number of colleges that are on quarter systems__ by looking at Winter 2023, the latest available Winter (Winter 2024 numbers are not yet updated for all colleges).<br>
# Then find the names of these colleges and __print their names as a comma separated string__, with text explanation.<br>
# The string will be long, let the names default to wrap around to the next line of output.
#
# Example print out:<br>
# `There are 35 colleges with Winter quarters out of 121 colleges`<br>
# `They are:`<br>
# `Allan Hancock, Butte, Canyons...`

# %%
quarter_system_colleges = clean_df[clean_df['Winter 2023'].notna()]

# Count and print the names of these colleges
number_of_quarter_system_colleges = len(quarter_system_colleges)
total_colleges = len(clean_df)
college_names = ', '.join(quarter_system_colleges.index)
print(f"There are {number_of_quarter_system_colleges} colleges with Winter quarters out of {total_colleges} colleges")
print("They are:")
print(college_names)
# Out:
# There are 35 colleges with Winter quarters out of 121 colleges
# They are:
# Allan Hancock, Butte, Canyons, Citrus, Compton, Deanza, Desert, East LA, El Camino, Feather River, Foothill, Glendale, Imperial, LA City, LA Harbor, LA Mission, LA Pierce, LA Swest, LA Trade, LA Valley, Lake Tahoe, Long Beach, Mission, Moreno Valley, Mt San Antonio, Norco College, Rio Hondo, Riverside, Santa Ana, Santa Monica, Santiago Canyon, Siskiyous, Victor Valley, West LA, West Valley

# %% [markdown]
# 7b. Using the college names that you found in step 7a, __create a DataFrame of only the colleges on the quarter system__.<br>
# Then __print the number of rows of the DataFrame__,<br>
# and __print the first 8 rows of the new DataFrame__.<br>
#
# _You should not have to type in each college name._

# %%
quarter_system_df = clean_df.loc[quarter_system_colleges.index]
print(f"Number of rows: {len(quarter_system_df)}")
quarter_system_df.head(8)
# Out:
# Number of rows: 35
#                Fall 2013  Winter 2014  Spring 2014  Summer 2014  Fall 2014  \
# Unnamed: 0
# Allan Hancock    15553.0          NaN      16894.0       7653.0    16461.0
# Butte            12982.0          NaN      12425.0       3372.0    13400.0
# Canyons          19950.0       5994.0      20134.0       9775.0    20938.0
# Citrus           13534.0       5131.0      13225.0       7345.0    13396.0
# Compton           7787.0          NaN       7232.0       4443.0     7728.0
# Deanza           23397.0      21462.0      20977.0      13823.0    23258.0
# Desert           10729.0          NaN       9987.0       3148.0    11079.0
# East LA          39162.0       9370.0      35162.0      17019.0    37469.0
#
#                Winter 2015  Spring 2015  Summer 2015  Fall 2015  Winter 2016  \
# Unnamed: 0
# Allan Hancock          NaN      17724.0       7991.0    15712.0       1079.0
# Butte               1585.0      12197.0       3376.0    13195.0       1724.0
# Canyons             6081.0      19702.0       9591.0    20738.0       6300.0
# Citrus              5739.0      12941.0       8081.0    13665.0       6467.0
# Compton                NaN       6974.0       4202.0     7461.0          NaN
# Deanza             20780.0      20399.0      13111.0    22713.0      20700.0
# Desert              1155.0      10912.0       3733.0    12306.0       1723.0
# East LA            11346.0      36287.0      19109.0    39115.0      11331.0
#
#                ...  Fall 2021  Winter 2022  Spring 2022  Summer 2022  \
# Unnamed: 0     ...
# Allan Hancock  ...    12208.0       1221.0      11858.0       5192.0
# Butte          ...    10173.0       1826.0       8721.0       2664.0
# Canyons        ...    19883.0       9117.0      19268.0      12254.0
# Citrus         ...    10375.0       4219.0       9223.0       6200.0
# Compton        ...     4360.0       1181.0       3818.0       2191.0
# Deanza         ...    17104.0      15195.0      14607.0       9934.0
# Desert         ...    10998.0       1683.0      11238.0       5446.0
# East LA        ...    31373.0       7582.0      27762.0      18656.0
#
#                Fall 2022  Winter 2023  Spring 2023  Summer 2023  Fall 2023  \
# Unnamed: 0
# Allan Hancock    11984.0       1473.0      12327.0       5478.0    12873.0
# Butte            10171.0       1715.0       9495.0       2989.0    11030.0
# Canyons          21621.0       9888.0      22127.0      10654.0    19781.0
# Citrus           10267.0       4593.0       9672.0       6382.0    10281.0
# Compton           4262.0       1373.0       4118.0       2828.0     4919.0
# Deanza           16411.0      14826.0      14274.0      10323.0    17190.0
# Desert           11742.0       1885.0      11388.0       5585.0    12124.0
# East LA          30191.0       9821.0      30677.0      18981.0    32679.0
#
#                Winter 2024
# Unnamed: 0
# Allan Hancock       1818.0
# Butte               2364.0
# Canyons            10654.0
# Citrus              4933.0
# Compton                NaN
# Deanza                 NaN
# Desert                 NaN
# East LA            10361.0
#
# [8 rows x 42 columns]

# %% [markdown]
# 7c. Observing the output of step 7b, note that there are still NaNs for Winter quarters for some of the colleges.<br>
# Why do you think the NaNs are still there?<br>
# __Create a Raw NBConvert cell to explain your answer__.

# %% [markdown]
# Some colleges still show NaNs for Winter quarters despite being on a quarter system. This may occur if the data for that particular Winter quarter is not updated or available due to delays in data entry or collection. Other reasons could include administrative errors or changes in reporting standards at the college.

# %% [markdown]
# #### B. Enrollment per school in the last 10 years

# %% [markdown]
# 8. Do the following steps to find the average number of students for each academic year at each school.
#
# 8a. An academic year has 4 terms: Fall, Winter, Spring, Summer.<br>
# Start with the cleaned DataFrame in step 6d, __create a new DataFrame with the average student count for the first academic year__.<br>
# This means find the average student count of the first 4 columns, for each college, and store the average count in the new DataFrame with the column label 2013.<br>
#
# First few lines of DataFrame:<br>
# ` 	                    2013`<br>
# `Unnamed: 0 	            `<br>
# `Alameda 	     5231.333333`<br>
# `Allan Hancock 	13366.666667`<br>

# %%
year_labels = ['Fall ' + str(year) for year in range(2013, 2024)]
academic_years_df = pd.DataFrame(index=clean_df.index)

# %% [markdown]
# 8b. Continue with the rest of the columns:
# - __find the average of every 4 columns__ (for the 4 terms of the year), but don't forget to stop when reaching Fall 2023, since this current academic year (2023-2024) is not done yet.
# - __add the average to the DataFrame of step 8a, with the columnn label which is the year of the Fall term__.<br>
# _You should not have to type the column label string, use the year of the Fall term instead_.
#
# Then __print the first rows of the DataFrame__.

# %%
for i in range(0, len(clean_df.columns) - 4, 4):  # Stop before Fall 2023
    year = year_labels[int(i/4)]
    academic_years_df[year] = clean_df.iloc[:, i:i+4].mean(axis=1)

academic_years_df.head()
# Out:
#                     Fall 2013     Fall 2014     Fall 2015     Fall 2016  \
# Unnamed: 0
# Alameda           5231.333333   5024.333333   5229.666667   4917.333333
# Allan Hancock    13366.666667  14058.666667  10380.750000   9987.250000
# American River   23465.000000  23892.666667  25450.000000  24796.333333
# Antelope Valley   9014.000000   9204.000000   9261.750000   9173.500000
# Bakersfield      14514.000000  15271.333333  16868.333333  18575.333333
#
#                     Fall 2017     Fall 2018     Fall 2019     Fall 2020  \
# Unnamed: 0
# Alameda           5070.333333   5079.333333   4754.000000   4421.666667
# Allan Hancock     9516.250000   9049.750000   8652.750000   7254.250000
# American River   25649.000000  25450.333333  23726.000000  20449.333333
# Antelope Valley   9395.750000   9372.500000   9204.500000   9526.333333
# Bakersfield      20222.000000  21746.000000  22521.333333  20924.333333
#
#                     Fall 2021     Fall 2022
# Unnamed: 0
# Alameda           3883.333333   4383.000000
# Allan Hancock     7619.750000   7815.500000
# American River   20850.666667  22661.666667
# Antelope Valley   8912.333333   9713.666667
# Bakersfield      22090.000000  24403.333333

# %% [markdown]
# 9. Do the following steps to fnd the distribution of students per school for the last 10 years.
#
# 9a. Now that you have the average count of students for each year and for each school,<br>
# __find the average student count for the last 10 years__ (2013-2022) and store in a Series.<br>
# Then __print the Series__.

# %%
average_student_count = academic_years_df.iloc[:, :10].mean(axis=1)
print(average_student_count)
# Out:
# Unnamed: 0
# Alameda                4799.433333
# Allan Hancock          9770.158333
# American River        23639.100000
# Antelope Valley        9277.833333
# Bakersfield           19713.600000
#                           ...
# West Hills Lemoore     3599.233333
# West LA                8121.550000
# West Valley            7422.108333
# Woodland               2905.800000
# Yuba                   5096.066667
# Length: 121, dtype: float64

# %% [markdown]
# 9b. From the output of step 9a, __use an appropriate plot to show the distribution of average student count per school__.<br>
# The plot should have: a title, x-axis label and y-axis label that explains what the x and y data are.<br>
# Use a grid to make the plot easier to read.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
average_student_count.hist(grid=True, bins=30, rwidth=0.9)
plt.title('Distribution of Average Student Count per School (2013-2022)')
plt.xlabel('Average Student Count')
plt.ylabel('Number of Schools')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# 9c. Use a pandas function to __show the basic statistics for the average student count per school__.

# %%
statistics = average_student_count.describe()
print(statistics)
# Out:
# count      121.000000
# mean     10376.460360
# std       6363.469793
# min        725.194444
# 25%       5425.900000
# 50%       9237.933333
# 75%      14246.616667
# max      31802.150000
# dtype: float64

# %% [markdown]
# 9d. Do the plot of step 9b and the statistics of step 9c agree with each other?<br>
# __Create a Raw NBConvert cell to explain your answer__.

# %% [markdown]
# The histogram and the statistical summary should agree with each other as the histogram visually represents the distribution outlined by the statistics. For example, the mean and median provide central tendency which should be evident in the histogram’s peak, while the standard deviation reflects the spread of data which indicates how spread out the histogram's bars are.

# %% [markdown]
# #### C. Enrollment trend of the largest colleges

# %% [markdown]
# 10. Do the following steps to find the enrollment trend of the 8 colleges with the largest enrollment.
#
# 10a. __Sort the average student count__ and __print the top 8 colleges and their student counts__.

# %%
top_8_colleges = average_student_count.sort_values(ascending=False).head(8)
print(top_8_colleges)
# Out:
# Unnamed: 0
# Mt San Antonio        31802.150000
# Santa Ana             28223.075000
# East LA               25398.225000
# American River        23639.100000
# Saddleback            23274.966667
# Santa Monica          22894.525000
# San Francisco Ctrs    22162.095238
# Pasadena              22074.125000
# dtype: float64

# %% [markdown]
# 10b.  __Use an appropriate plot to show the trend of student counts in the past 10 years__ of the top 8 colleges.<br>
#
# - The plot should have: a title, x-axis label and y-axis label that explains what the x and y data are, and with each college name clearly noted.<br>
# - Use a grid to make the plot easier to read.
# - Adjust the size of the plot so there's no overlapping of any features in the plot.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7)) 
for college in top_8_colleges.index:
    plt.plot(academic_years_df.columns, academic_years_df.loc[college], marker='o', label=college)

plt.title('Enrollment Trend for the Top 8 Colleges (2013-2023)')
plt.xlabel('Academic Year')
plt.ylabel('Average Student Count')
plt.legend(title='College Names', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 10c. A data analyst is especially valuable when that person is an expert in a specific domain, so that the person can give insights when interpreting the results from the data.<br>
# You are the domain expert in being a student at a community college, therefore:<br>
# __Create a Raw NBConvert cell to answer the following questions__:
# - What is the general enrollment trend at these colleges?
# - What could explain the unusual pattern in 2020-2021?

# %% [markdown]
# The general trend for the top 8 colleges shows increasing or stable student numbers, with a significant dip in most cases during the 2020-2021 academic year. This unusual pattern can be attributed to the global COVID-19 pandemic, which led to temporary college closures, shifts to online learning, and overall disruption in educational activities.

# %% [markdown]
# #### D. Recent change in enrollment for local community colleges

# %% [markdown]
# 11. Do the following steps to find the percentage change in enrollment between Fall 2021 and Fall 2023, the most current year, for <u>local</u> community colleges.
#
# 11a. Using the cleaned DataFrame from step 6d, __find the percentage change in student counts between Fall 2021 and Fall 2023__ and store in a Series.<br>
# Then use the given `colleges` list below to __find the percentage change for the local colleges__.
#
# The local colleges are:<br>
# `colleges = ['Deanza','Evergreen Valley','Foothill','Mission','San Jose City','West Valley']`
#
# _Percentage change = (new value - old value) / old value * 100_

# %%
percentage_change = ((clean_df['Fall 2023'] - clean_df['Fall 2021']) / clean_df['Fall 2021']) * 100
local_colleges_change = percentage_change.loc[['Deanza', 'Evergreen Valley', 'Foothill', 'Mission', 'San Jose City', 'West Valley']]
print(local_colleges_change)
# Out:
# Unnamed: 0
# Deanza               0.502806
# Evergreen Valley    12.080049
# Foothill             0.215533
# Mission              7.333533
# San Jose City       16.180064
# West Valley         17.417152
# dtype: float64

# %% [markdown]
# 11b. __Use an appropriate plot to show the enrollment change for the local colleges__.<br>
# The plot should have: a title, x-axis label and y-axis label that explain what the x and y data are, and with each college name clearly noted.<br>
# Use a grid to make the plot easier to read.

# %%
plt.figure(figsize=(10, 6))
local_colleges_change.plot(kind='bar', color='red')
plt.title('Percentage Change in Enrollment for Local Colleges (2021-2023)')
plt.xlabel('College')
plt.ylabel('Percentage Change')
plt.axhline(0, color='grey', linewidth=0.8)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
